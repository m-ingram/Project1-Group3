# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.ticker as ticker

# %%
#Study data files
team_salary_merged_path = "Output/team_salary_merged.csv"

#Read Study Results
team_salary_merged = pd.read_csv(team_salary_merged_path)
team_salary_merged.head()
# Out:
#    yearID lgID teamID franchID divID  Rank    G  Ghome   W   L  ...  BPF  PPF  \
# 0    1985   NL    ATL      ATL     W     5  162   81.0  66  96  ...  105  106
# 1    1985   AL    BAL      BAL     E     4  161   81.0  83  78  ...   97   97
# 2    1985   AL    BOS      BOS     E     5  163   81.0  81  81  ...  104  104
# 3    1985   AL    CAL      ANA     W     2  162   79.0  90  72  ...  100  100
# 4    1985   AL    CHA      CHW     W     3  163   81.0  85  77  ...  104  104
#
#   teamIDBR teamIDlahman45  teamIDretro  total_player_salaries  \
# 0      ATL            ATL          ATL               14807000
# 1      BAL            BAL          BAL               11560712
# 2      BOS            BOS          BOS               10897560
# 3      CAL            CAL          CAL               14427894
# 4      CHW            CHA          CHA                9846178
#
#    med_player_salary  min_player_salary  max_player_salary    salary_var
# 0           620833.5             120000            1625000  1.576369e+11
# 1           497916.5              60000            1472819  1.017152e+11
# 2           325000.0             115000            1075000  8.910658e+10
# 3           493750.0              60000            1100000  9.319582e+10
# 4           333333.0              60000            1242333  1.184021e+11
#
# [5 rows x 53 columns]

# %%
# Most wins from higher to lower
top_wins = team_salary_merged.sort_values(["W"],ascending=False)
top_wins.head(30)
# Out:
#      yearID lgID teamID franchID divID  Rank    G  Ghome    W   L  ...  BPF  \
# 437    2001   AL    SEA      SEA     W     1  162   81.0  116  46  ...   94
# 353    1998   AL    NYA      NYY     E     1  162   81.0  114  48  ...   97
# 42     1986   NL    NYN      NYM     E     1  162   81.0  108  54  ...   98
# 339    1998   NL    ATL      ATL     E     1  162   81.0  106  56  ...  100
# 517    2004   NL    SLN      STL     C     1  162   81.0  105  57  ...  100
# 208    1993   NL    ATL      ATL     W     1  162   81.0  104  58  ...  101
# 95     1988   AL    OAK      OAK     W     1  162   81.0  104  58  ...   97
# 459    2002   AL    OAK      OAK     W     1  162   81.0  103  59  ...   98
# 457    2002   AL    NYA      NYY     E     1  161   80.0  103  58  ...  100
# 365    1999   NL    ATL      ATL     E     1  162   81.0  103  59  ...  100
# 638    2009   AL    NYA      NYY     E     1  162   81.0  103  59  ...  105
# 230    1993   NL    SFN      SFG     W     2  162   81.0  103  59  ...   97
# 147    1990   AL    OAK      OAK     W     1  162   81.0  103  59  ...   96
# 693    2011   NL    PHI      PHI     E     1  162   81.0  102  60  ...  105
# 347    1998   NL    HOU      HOU     C     1  162   81.0  102  60  ...   98
# 433    2001   AL    OAK      OAK     W     2  162   81.0  102  60  ...   99
# 23     1985   NL    SLN      STL     E     1  162   81.0  101  61  ...  100
# 509    2004   AL    NYA      NYY     E     1  162   81.0  101  61  ...   98
# 483    2003   AL    NYA      NYY     E     1  163   82.0  101  61  ...   98
# 443    2002   NL    ATL      ATL     E     1  161   81.0  101  59  ...  102
# 313    1997   NL    ATL      ATL     E     1  162   81.0  101  61  ...  102
# 469    2003   NL    ATL      ATL     E     1  162   81.0  101  61  ...  101
# 542    2005   NL    SLN      STL     C     1  162   81.0  100  62  ...  101
# 794    2015   NL    SLN      STL     C     1  162   81.0  100  62  ...  102
# 490    2003   NL    SFN      SFG     W     1  161   81.0  100  61  ...   99
# 94     1988   NL    NYN      NYM     E     1  160   80.0  100  60  ...   95
# 267    1995   AL    CLE      CLE     C     1  144   72.0  100  44  ...  101
# 608    2008   AL    LAA      ANA     W     1  162   81.0  100  62  ...  103
# 293    1996   AL    CLE      CLE     C     1  161   80.0   99  62  ...   99
# 523    2005   AL    CHA      CHW     C     1  162   81.0   99  63  ...  103
#
#      PPF teamIDBR teamIDlahman45  teamIDretro  total_player_salaries  \
# 437   93      SEA            SEA          SEA               74720834
# 353   95      NYY            NYA          NYA               66806867
# 42    96      NYM            NYN          NYN               15393714
# 339   98      ATL            ATL          ATL               61186000
# 517   99      STL            SLN          SLN               83228333
# 208  100      ATL            ATL          ATL               41641417
# 95    96      OAK            OAK          OAK                9690000
# 459   97      OAK            OAK          OAK               40004167
# 457   99      NYY            NYA          NYA              125928583
# 365   98      ATL            ATL          ATL               73140000
# 638  103      NYY            NYA          NYA              201449189
# 230   96      SFG            SFN          SFN               35050000
# 147   95      OAK            OAK          OAK               19887501
# 693  103      PHI            PHI          PHI              172976379
# 347   97      HOU            HOU          HOU               42374000
# 433   97      OAK            OAK          OAK               33810750
# 23    99      STL            SLN          SLN               11817083
# 509   97      NYY            NYA          NYA              184193950
# 483   97      NYY            NYA          NYA              152749814
# 443  101      ATL            ATL          ATL               92870367
# 313   99      ATL            ATL          ATL               52278500
# 469  100      ATL            ATL          ATL              106243667
# 542  100      STL            SLN          SLN               92106833
# 794  101      STL            SLN          SLN              119241500
# 490   98      SFG            SFN          SFN               82852167
# 94    94      NYM            NYN          NYN               15269314
# 267   99      CLE            CLE          CLE               37937835
# 608  102      LAA            ANA          ANA              119216333
# 293   98      CLE            CLE          CLE               48107360
# 523  103      CHW            CHA          CHA               75178000
#
#      med_player_salary  min_player_salary  max_player_salary    salary_var
# 437          1925000.0             202500            7000000  4.933991e+12
# 353           970833.5             170000            8300000  4.949012e+12
# 42            255000.0              60000            2800000  4.589444e+11
# 339           297500.0             170000            9600000  7.692754e+12
# 517          1100000.0             300000           12500000  1.348806e+13
# 208           725000.0             109000            5875000  2.128835e+12
# 95            325000.0              62500            1300000  1.152289e+11
# 459           812500.0             202000            7166667  3.340018e+12
# 457          2500000.0             210000           14600000  1.982178e+13
# 365          1000000.0             200000           10600000  8.813876e+12
# 638          5200000.0             400000           33000000  7.389824e+13
# 230           475000.0             109000            4750000  1.747640e+12
# 147           405000.0             100000            2350000  3.352870e+11
# 693          2625000.0             414000           20000000  3.878239e+13
# 347           550000.0             170000            7945000  3.730955e+12
# 433           350000.0             201000            7100000  2.767633e+12
# 23            457500.0              60000            1555000  1.675319e+11
# 509          3100000.0             301400           22000000  4.036401e+13
# 483          4575000.0             300000           15600000  2.285926e+13
# 443          1506250.0             200000           13100000  1.603583e+13
# 313           250000.0             150000            7000000  4.730073e+12
# 469           800000.0             300000           14750000  2.563566e+13
# 542          2166666.5             320000           12666667  1.532588e+13
# 794          2000000.0             507500           19500000  3.365258e+13
# 490          1937500.0             300000           15500000  1.231130e+13
# 94            537500.0              62500            2160714  3.362161e+11
# 267           516666.0             109000            4550000  1.626652e+12
# 608          1200000.0             390000           16500000  2.611594e+13
# 293           750000.0             110000            5700000  2.723674e+12
# 523          2000000.0             318000            8750000  7.509268e+12
#
# [30 rows x 53 columns]

# %%
#Wins selected by year ( All teams)
top_wins_group = top_wins.groupby("yearID").apply(lambda x: x.sort_values('W',ascending=False))

top_wins_group.head()
# Out:
#            yearID lgID teamID franchID divID  Rank    G  Ghome    W   L  ...  \
# yearID                                                                   ...
# 1985   23    1985   NL    SLN      STL     E     1  162   81.0  101  61  ...
#        25    1985   AL    TOR      TOR     E     1  161   80.0   99  62  ...
#        16    1985   NL    NYN      NYM     E     2  162   81.0   98  64  ...
#        15    1985   AL    NYA      NYY     E     2  161   80.0   97  64  ...
#        11    1985   NL    LAN      LAD     W     1  162   81.0   95  67  ...
#
#            BPF  PPF teamIDBR teamIDlahman45  teamIDretro  \
# yearID
# 1985   23  100   99      STL            SLN          SLN
#        25  104  103      TOR            TOR          TOR
#        16   99   97      NYM            NYN          NYN
#        15   98   97      NYY            NYA          NYA
#        11   97   96      LAD            LAN          LAN
#
#            total_player_salaries  med_player_salary  min_player_salary  \
# yearID
# 1985   23               11817083           457500.0              60000
#        25                8812550           353150.0              60000
#        16               10834762           325000.0              60000
#        15               14238204           618750.0             100000
#        11               10967917           435000.0              60000
#
#            max_player_salary    salary_var
# yearID
# 1985   23            1555000  1.675319e+11
#        25            1000000  7.582151e+10
#        16            2028571  2.973267e+11
#        15            1795704  1.956184e+11
#        11            1270000  1.073127e+11
#
# [5 rows x 53 columns]

# %%
# Team with most victories by year 
dataframe = top_wins_group.drop_duplicates(subset=['yearID'])
dataframe
# Out:
#             yearID lgID teamID franchID divID  Rank    G  Ghome    W   L  ...  \
# yearID                                                                    ...
# 1985   23     1985   NL    SLN      STL     E     1  162   81.0  101  61  ...
# 1986   42     1986   NL    NYN      NYM     E     1  162   81.0  108  54  ...
# 1987   60     1987   AL    DET      DET     E     1  162   81.0   98  64  ...
# 1988   95     1988   AL    OAK      OAK     W     1  162   81.0  104  58  ...
# 1989   121    1989   AL    OAK      OAK     W     1  162   81.0   99  63  ...
# 1990   147    1990   AL    OAK      OAK     W     1  162   81.0  103  59  ...
# 1991   175    1991   NL    PIT      PIT     E     1  162   84.0   98  64  ...
# 1992   182    1992   NL    ATL      ATL     W     1  162   81.0   98  64  ...
# 1993   208    1993   NL    ATL      ATL     W     1  162   81.0  104  58  ...
# 1994   248    1994   NL    MON      WSN     E     1  114   52.0   74  40  ...
# 1995   267    1995   AL    CLE      CLE     C     1  144   72.0  100  44  ...
# 1996   293    1996   AL    CLE      CLE     C     1  161   80.0   99  62  ...
# 1997   313    1997   NL    ATL      ATL     E     1  162   81.0  101  61  ...
# 1998   353    1998   AL    NYA      NYY     E     1  162   81.0  114  48  ...
# 1999   365    1999   NL    ATL      ATL     E     1  162   81.0  103  59  ...
# 2000   412    2000   NL    SFN      SFG     W     1  162   81.0   97  65  ...
# 2001   437    2001   AL    SEA      SEA     W     1  162   81.0  116  46  ...
# 2002   459    2002   AL    OAK      OAK     W     1  162   81.0  103  59  ...
# 2003   483    2003   AL    NYA      NYY     E     1  163   82.0  101  61  ...
# 2004   517    2004   NL    SLN      STL     C     1  162   81.0  105  57  ...
# 2005   542    2005   NL    SLN      STL     C     1  162   81.0  100  62  ...
# 2006   561    2006   NL    NYN      NYM     E     1  162   81.0   97  65  ...
# 2007   574    2007   AL    BOS      BOS     E     1  162   81.0   96  66  ...
# 2008   608    2008   AL    LAA      ANA     W     1  162   81.0  100  62  ...
# 2009   638    2009   AL    NYA      NYY     E     1  162   81.0  103  59  ...
# 2010   667    2010   NL    PHI      PHI     E     1  162   84.0   97  65  ...
# 2011   693    2011   NL    PHI      PHI     E     1  162   81.0  102  60  ...
# 2012   727    2012   NL    WAS      WSN     E     1  162   81.0   98  64  ...
# 2013   750    2013   NL    SLN      STL     C     1  162   81.0   97  65  ...
# 2014   764    2014   AL    LAA      ANA     W     1  162   81.0   98  64  ...
# 2015   794    2015   NL    SLN      STL     C     1  162   81.0  100  62  ...
#
#             BPF  PPF teamIDBR teamIDlahman45  teamIDretro  \
# yearID
# 1985   23   100   99      STL            SLN          SLN
# 1986   42    98   96      NYM            NYN          NYN
# 1987   60    96   95      DET            DET          DET
# 1988   95    97   96      OAK            OAK          OAK
# 1989   121   97   95      OAK            OAK          OAK
# 1990   147   96   95      OAK            OAK          OAK
# 1991   175   99   98      PIT            PIT          PIT
# 1992   182  107  105      ATL            ATL          ATL
# 1993   208  101  100      ATL            ATL          ATL
# 1994   248  101  101      MON            MON          MON
# 1995   267  101   99      CLE            CLE          CLE
# 1996   293   99   98      CLE            CLE          CLE
# 1997   313  102   99      ATL            ATL          ATL
# 1998   353   97   95      NYY            NYA          NYA
# 1999   365  100   98      ATL            ATL          ATL
# 2000   412   93   92      SFG            SFN          SFN
# 2001   437   94   93      SEA            SEA          SEA
# 2002   459   98   97      OAK            OAK          OAK
# 2003   483   98   97      NYY            NYA          NYA
# 2004   517  100   99      STL            SLN          SLN
# 2005   542  101  100      STL            SLN          SLN
# 2006   561   98   97      NYM            NYN          NYN
# 2007   574  106  105      BOS            BOS          BOS
# 2008   608  103  102      LAA            ANA          ANA
# 2009   638  105  103      NYY            NYA          NYA
# 2010   667  101  100      PHI            PHI          PHI
# 2011   693  105  103      PHI            PHI          PHI
# 2012   727   99  101      WSN            MON          WAS
# 2013   750   99   97      STL            SLN          SLN
# 2014   764   96   95      LAA            ANA          ANA
# 2015   794  102  101      STL            SLN          SLN
#
#             total_player_salaries  med_player_salary  min_player_salary  \
# yearID
# 1985   23                11817083           457500.0              60000
# 1986   42                15393714           255000.0              60000
# 1987   60                12122881           420000.0              62500
# 1988   95                 9690000           325000.0              62500
# 1989   121               15613070           572500.0              68000
# 1990   147               19887501           405000.0             100000
# 1991   175               23634667           600000.0             105000
# 1992   182               34625333           600000.0             109000
# 1993   208               41641417           725000.0             109000
# 1994   248               19098000           187500.0             109000
# 1995   267               37937835           516666.0             109000
# 1996   293               48107360           750000.0             110000
# 1997   313               52278500           250000.0             150000
# 1998   353               66806867           970833.5             170000
# 1999   365               73140000          1000000.0             200000
# 2000   412               53737826          1150000.0             200000
# 2001   437               74720834          1925000.0             202500
# 2002   459               40004167           812500.0             202000
# 2003   483              152749814          4575000.0             300000
# 2004   517               83228333          1100000.0             300000
# 2005   542               92106833          2166666.5             320000
# 2006   561              101084963           912500.0             327000
# 2007   574              143026214          3591666.5             380000
# 2008   608              119216333          1200000.0             390000
# 2009   638              201449189          5200000.0             400000
# 2010   667              141928379          2750000.0             400000
# 2011   693              172976379          2625000.0             414000
# 2012   727               80855143           807500.0             481000
# 2013   750               92260110           518500.0             490000
# 2014   764              121988250           870000.0             500500
# 2015   794              119241500          2000000.0             507500
#
#             max_player_salary    salary_var
# yearID
# 1985   23             1555000  1.675319e+11
# 1986   42             2800000  4.589444e+11
# 1987   60             1850000  1.936324e+11
# 1988   95             1300000  1.152289e+11
# 1989   121            1600000  2.153701e+11
# 1990   147            2350000  3.352870e+11
# 1991   175            3350000  7.479406e+11
# 1992   182            3183333  1.035898e+12
# 1993   208            5875000  2.128835e+12
# 1994   248            4025000  1.176331e+12
# 1995   267            4550000  1.626652e+12
# 1996   293            5700000  2.723674e+12
# 1997   313            7000000  4.730073e+12
# 1998   353            8300000  4.949012e+12
# 1999   365           10600000  8.813876e+12
# 2000   412           10658826  6.607521e+12
# 2001   437            7000000  4.933991e+12
# 2002   459            7166667  3.340018e+12
# 2003   483           15600000  2.285926e+13
# 2004   517           12500000  1.348806e+13
# 2005   542           12666667  1.532588e+13
# 2006   561           14875000  2.307302e+13
# 2007   574           17016381  2.433319e+13
# 2008   608           16500000  2.611594e+13
# 2009   638           33000000  7.389824e+13
# 2010   667           19000000  2.876030e+13
# 2011   693           20000000  3.878239e+13
# 2012   727           13571428  1.338012e+13
# 2013   750           16272110  2.316121e+13
# 2014   764           23000000  4.023419e+13
# 2015   794           19500000  3.365258e+13
#
# [31 rows x 53 columns]

# %%
not_strike= dataframe.copy(deep=True)
not_strike = not_strike[not_strike['yearID']!=1994]
not_strike['log_salary'] = np.log(not_strike['total_player_salaries'])
not_strike.head(30)
# Out:
#             yearID lgID teamID franchID divID  Rank    G  Ghome    W   L  ...  \
# yearID                                                                    ...
# 1985   23     1985   NL    SLN      STL     E     1  162   81.0  101  61  ...
# 1986   42     1986   NL    NYN      NYM     E     1  162   81.0  108  54  ...
# 1987   60     1987   AL    DET      DET     E     1  162   81.0   98  64  ...
# 1988   95     1988   AL    OAK      OAK     W     1  162   81.0  104  58  ...
# 1989   121    1989   AL    OAK      OAK     W     1  162   81.0   99  63  ...
# 1990   147    1990   AL    OAK      OAK     W     1  162   81.0  103  59  ...
# 1991   175    1991   NL    PIT      PIT     E     1  162   84.0   98  64  ...
# 1992   182    1992   NL    ATL      ATL     W     1  162   81.0   98  64  ...
# 1993   208    1993   NL    ATL      ATL     W     1  162   81.0  104  58  ...
# 1995   267    1995   AL    CLE      CLE     C     1  144   72.0  100  44  ...
# 1996   293    1996   AL    CLE      CLE     C     1  161   80.0   99  62  ...
# 1997   313    1997   NL    ATL      ATL     E     1  162   81.0  101  61  ...
# 1998   353    1998   AL    NYA      NYY     E     1  162   81.0  114  48  ...
# 1999   365    1999   NL    ATL      ATL     E     1  162   81.0  103  59  ...
# 2000   412    2000   NL    SFN      SFG     W     1  162   81.0   97  65  ...
# 2001   437    2001   AL    SEA      SEA     W     1  162   81.0  116  46  ...
# 2002   459    2002   AL    OAK      OAK     W     1  162   81.0  103  59  ...
# 2003   483    2003   AL    NYA      NYY     E     1  163   82.0  101  61  ...
# 2004   517    2004   NL    SLN      STL     C     1  162   81.0  105  57  ...
# 2005   542    2005   NL    SLN      STL     C     1  162   81.0  100  62  ...
# 2006   561    2006   NL    NYN      NYM     E     1  162   81.0   97  65  ...
# 2007   574    2007   AL    BOS      BOS     E     1  162   81.0   96  66  ...
# 2008   608    2008   AL    LAA      ANA     W     1  162   81.0  100  62  ...
# 2009   638    2009   AL    NYA      NYY     E     1  162   81.0  103  59  ...
# 2010   667    2010   NL    PHI      PHI     E     1  162   84.0   97  65  ...
# 2011   693    2011   NL    PHI      PHI     E     1  162   81.0  102  60  ...
# 2012   727    2012   NL    WAS      WSN     E     1  162   81.0   98  64  ...
# 2013   750    2013   NL    SLN      STL     C     1  162   81.0   97  65  ...
# 2014   764    2014   AL    LAA      ANA     W     1  162   81.0   98  64  ...
# 2015   794    2015   NL    SLN      STL     C     1  162   81.0  100  62  ...
#
#             PPF teamIDBR teamIDlahman45 teamIDretro  total_player_salaries  \
# yearID
# 1985   23    99      STL            SLN         SLN               11817083
# 1986   42    96      NYM            NYN         NYN               15393714
# 1987   60    95      DET            DET         DET               12122881
# 1988   95    96      OAK            OAK         OAK                9690000
# 1989   121   95      OAK            OAK         OAK               15613070
# 1990   147   95      OAK            OAK         OAK               19887501
# 1991   175   98      PIT            PIT         PIT               23634667
# 1992   182  105      ATL            ATL         ATL               34625333
# 1993   208  100      ATL            ATL         ATL               41641417
# 1995   267   99      CLE            CLE         CLE               37937835
# 1996   293   98      CLE            CLE         CLE               48107360
# 1997   313   99      ATL            ATL         ATL               52278500
# 1998   353   95      NYY            NYA         NYA               66806867
# 1999   365   98      ATL            ATL         ATL               73140000
# 2000   412   92      SFG            SFN         SFN               53737826
# 2001   437   93      SEA            SEA         SEA               74720834
# 2002   459   97      OAK            OAK         OAK               40004167
# 2003   483   97      NYY            NYA         NYA              152749814
# 2004   517   99      STL            SLN         SLN               83228333
# 2005   542  100      STL            SLN         SLN               92106833
# 2006   561   97      NYM            NYN         NYN              101084963
# 2007   574  105      BOS            BOS         BOS              143026214
# 2008   608  102      LAA            ANA         ANA              119216333
# 2009   638  103      NYY            NYA         NYA              201449189
# 2010   667  100      PHI            PHI         PHI              141928379
# 2011   693  103      PHI            PHI         PHI              172976379
# 2012   727  101      WSN            MON         WAS               80855143
# 2013   750   97      STL            SLN         SLN               92260110
# 2014   764   95      LAA            ANA         ANA              121988250
# 2015   794  101      STL            SLN         SLN              119241500
#
#             med_player_salary  min_player_salary  max_player_salary  \
# yearID
# 1985   23            457500.0              60000            1555000
# 1986   42            255000.0              60000            2800000
# 1987   60            420000.0              62500            1850000
# 1988   95            325000.0              62500            1300000
# 1989   121           572500.0              68000            1600000
# 1990   147           405000.0             100000            2350000
# 1991   175           600000.0             105000            3350000
# 1992   182           600000.0             109000            3183333
# 1993   208           725000.0             109000            5875000
# 1995   267           516666.0             109000            4550000
# 1996   293           750000.0             110000            5700000
# 1997   313           250000.0             150000            7000000
# 1998   353           970833.5             170000            8300000
# 1999   365          1000000.0             200000           10600000
# 2000   412          1150000.0             200000           10658826
# 2001   437          1925000.0             202500            7000000
# 2002   459           812500.0             202000            7166667
# 2003   483          4575000.0             300000           15600000
# 2004   517          1100000.0             300000           12500000
# 2005   542          2166666.5             320000           12666667
# 2006   561           912500.0             327000           14875000
# 2007   574          3591666.5             380000           17016381
# 2008   608          1200000.0             390000           16500000
# 2009   638          5200000.0             400000           33000000
# 2010   667          2750000.0             400000           19000000
# 2011   693          2625000.0             414000           20000000
# 2012   727           807500.0             481000           13571428
# 2013   750           518500.0             490000           16272110
# 2014   764           870000.0             500500           23000000
# 2015   794          2000000.0             507500           19500000
#
#               salary_var  log_salary
# yearID
# 1985   23   1.675319e+11   16.285057
# 1986   42   4.589444e+11   16.549470
# 1987   60   1.936324e+11   16.310605
# 1988   95   1.152289e+11   16.086605
# 1989   121  2.153701e+11   16.563619
# 1990   147  3.352870e+11   16.805602
# 1991   175  7.479406e+11   16.978225
# 1992   182  1.035898e+12   17.360096
# 1993   208  2.128835e+12   17.544606
# 1995   267  1.626652e+12   17.451459
# 1996   293  2.723674e+12   17.688946
# 1997   313  4.730073e+12   17.772096
# 1998   353  4.949012e+12   18.017316
# 1999   365  8.813876e+12   18.107886
# 2000   412  6.607521e+12   17.799628
# 2001   437  4.933991e+12   18.129270
# 2002   459  3.340018e+12   17.504494
# 2003   483  2.285926e+13   18.844312
# 2004   517  1.348806e+13   18.237098
# 2005   542  1.532588e+13   18.338460
# 2006   561  2.307302e+13   18.431472
# 2007   574  2.433319e+13   18.778538
# 2008   608  2.611594e+13   18.596450
# 2009   638  7.389824e+13   19.121048
# 2010   667  2.876030e+13   18.770833
# 2011   693  3.878239e+13   18.968666
# 2012   727  1.338012e+13   18.208170
# 2013   750  2.316121e+13   18.340122
# 2014   764  4.023419e+13   18.619435
# 2015   794  3.365258e+13   18.596661
#
# [30 rows x 54 columns]

# %%
plt.figure(figsize=(14,9))  ## width, height
sns.scatterplot(x='yearID', y='total_player_salaries', data=not_strike, size= 'W', hue='franchID')
plt.xlabel('years')
plt.ylabel('Salary')
#plt.savefig('scatterplot')
plt.legend(bbox_to_anchor=(1.0, 1.0))
formatter = ticker.StrMethodFormatter('{x:,.0f}')
plt.gca().yaxis.set_major_formatter(formatter)
#plt.savefig("Output/Avg Regression Fig.png")
plt.show()

# %%
# Calculating Mean, Median , var, std sem of wins() good one
summary_aggr =  team_salary_merged.groupby(['franchID'])[['W']].agg(['mean'])
summary_aggr
# Out:
#                   W
#                mean
# franchID
# ANA       83.129032
# ATL       85.709677
# BAL       75.677419
# BOS       85.612903
# CHC       76.838710
# CHW       81.000000
# CIN       79.935484
# CLE       79.677419
# DET       76.387097
# HOU       79.419355
# KCR       74.290323
# LAD       83.774194
# MIL       76.451613
# MIN       78.290323
# NYM       81.935484
# NYY       90.129032
# OAK       83.903226
# PHI       78.838710
# PIT       74.290323
# SDP       76.935484
# SEA       77.354839
# SFG       83.064516
# STL       85.774194
# TEX       80.161290
# TOR       82.322581
# WSN       77.870968

# %%
# good one average of wins over the years
plt.figure(figsize=(14,10))  ## width, height
team_salary_merged.groupby('franchID')['W'].mean().plot.bar()
plt.xlabel('Teams')
plt.ylabel(' Avg Wins')
plt.title('Average of wins across years')
#plt.legend(bbox_to_anchor=(1.0, 1.0))
plt.show()

# %%
#Correlation between wins and Salary over the years( good one)
print(not_strike['W'].corr(not_strike['total_player_salaries']))
# Out:
# -0.1275451859549288
